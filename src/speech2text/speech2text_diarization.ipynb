# %%
import speech_recognition as sr
from deepmultilingualpunctuation import PunctuationModel
import time
import csv
import ffmpeg
import pandas as pd
import os
import sys


pathname = os.path.dirname(sys.argv[0])

# if os.path.exists("./../../../../../data/senato_project/data/speech2text/" + filename + ".txt"):
#     continue
filename = "Leg15NumSed33"
# aac_file = "./../../../../../data/senato_project/data/download_convert_video_aac/" + filename + ".aac"
wav_file = "./" + filename + ".wav"

# print("Inizio conversione wav")
# stream = ffmpeg.input(aac_file)
# stream = ffmpeg.output(stream, wav_file)
# ffmpeg.run(stream)
# print("Conversione wav completata")

# initialize the recognizer
r = sr.Recognizer()

# mettere la punteggiatura al testo estratto
model = PunctuationModel()

chunk_size = 120 # 2 minutes in seconds

audio_file = sr.AudioFile(wav_file)


f_text_speakers = open('../../data/speech2text_diarization/' + filename + '.csv', 'w')
writer_text_speakers = csv.writer(f_text_speakers, lineterminator='\n')
writer_text_speakers.writerow(["id_speaker", "text", "offset_video", "duration"])

print("Inizio: " + filename)
with audio_file as source:
    print(source.DURATION)
    duration_audio = source.DURATION
    with open('../../data/convert_rttm_to_csv/' + filename + '.csv', 'r') as file:
        reader = csv.reader(file)
        num_total_speech_speaker = sum(1 for _ in reader) - 1
        print(num_total_speech_speaker)
        file.seek(0)
        next(reader)  # Salta la prima riga (nomi delle colonne)
        count_speech_speaker = 1
        for row in reader:
            whole_text_speaker = ""
            id_speaker = row[0]
            start_speaker_offset = float(row[1]) - 2
            duration_speech_speaker = float(row[2])
            if start_speaker_offset < 0:
                start_speaker_offset = 0
            print(id_speaker + " " + str(start_speaker_offset) + " " + str(duration_speech_speaker))
            end_speaker_offset = start_speaker_offset + duration_speech_speaker
            if duration_audio > end_speaker_offset + 1:
                end_speaker_offset = end_speaker_offset + 1
            else:
                end_speaker_offset = duration_audio
            for i in range(int(start_speaker_offset), int(end_speaker_offset), chunk_size):
                start = i
                end = min(i + chunk_size, end_speaker_offset)
                source = sr.AudioFile(wav_file)
                with source as s:
                    r.adjust_for_ambient_noise(s)
                    try:
                        audio_data = r.record(s, duration=end-start, offset=start)
                        text = r.recognize_google(audio_data, language='it-IT')
                        whole_text_speaker += " " + text
                        print(whole_text_speaker)
                    except Exception as e:
                        print("-- Error")
                        print(e)
            print("-- Speech_speaker_" + str(count_speech_speaker) +"/ Speech_speaker_" + str(num_total_speech_speaker) + " completato")
            count_speech_speaker += 1
            try:
                result_text_punctuation = model.restore_punctuation(whole_text_speaker)
                writer_text_speakers.writerow([id_speaker, result_text_punctuation, start_speaker_offset, duration_speech_speaker])
            except Exception as e:
                pass



# scrivere il risultato dell'inserimento della punteggiatura su file
# os.remove(wav_file)
f_text_speakers.close()
print("Terminato: " + filename)

print("Execution complete!")
# Out:
# Inizio: Leg15NumSed33
# 10105.510022675737
# 149
# SPEAKER_09 1.4340000000000002 11.035999999999998
#  la seduta è aperta invito il senatore segretario a Dare lettura del processo verbale della seduta del 22 agosto 2000
# -- Speech_speaker_1/ Speech_speaker_149 completato
# SPEAKER_00 16.335 31.05
#  aperta la seduta alle ore 16:31 si legge sia prova il processo verbale della seduta pomeridiana del 2 agosto 2006 presidente dalle comunicazioni specificate in allegato il resoconto annuncio ai sensi dell'articolo 77 secondo comma della Costituzione la presentazione del disegno di legge numero 92 9 di conversione in legge del decreto legge numero 351 del 2006 ed aperta che il Senato tornerà a riunirsi in seduta pubblica martedì 19 settembre 2006 alle ore 17 con l'ordine del giorno di Guida alla lettura la seduta è tolta alle ore 16:30
# -- Speech_speaker_2/ Speech_speaker_149 completato
# SPEAKER_09 49.764 8.859999999999992
#  Grazie Se non ci sono interventi dichiariamo approvato al processo verbale
# -- Speech_speaker_3/ Speech_speaker_149 completato
# SPEAKER_10 58.623 0.186
# -- Error
#
# -- Speech_speaker_4/ Speech_speaker_149 completato
# SPEAKER_09 63.45 22.326
#  l'elenco dei senatori in concede assenti per incarico ricevuto Dal Senato Sarà pubblicato in allegato al resoconto della seduta odierna comunico che potranno effettuarsi votazioni con il sistema elettronico decorre perciò Da questo momento il termine di 20 minuti per il preavviso di cui all'articolo 119 comma 1 del regolamento
# -- Speech_speaker_5/ Speech_speaker_149 completato
# SPEAKER_10 89.133 0.034
# -- Error
#
# -- Speech_speaker_6/ Speech_speaker_149 completato
# SPEAKER_09 89.167 138.02100000000002
#  onorevoli colleghi rendo all'assemblea il triste annuncio della scomparsa del senatore Ignazio manusa deceduto improvvisamente il 24 agosto scorso ha 66 anni fortemente impegnato nella realtà politica della Sardegna il senatore manizha aveva una lunga carriera politica alle spalle già consigliere regionale sindaco di Oristano la tua città dal 81 al 84 Era stato eletto per la prima volta al Senato nella quattordicesima legislatura e quindi quella corrente nelle liste di Forza Italia recentemente aveva contribuito alla nascita del gruppo della Democrazia Cristiana indipendenti movimento per l'autonomia in Senato tu ce lo ricordiamo per il tratto mite e discreto e per la cinghia e sembrare presenza ai lavori parlamentari in aula è in commissione alla vedova signora Adriana ai figli ai colleghi del gruppo di appartenenza del suo partito agli elettori della Sardegna esprimo il cordoglio mio e personale dell'intera assemblea che vuoi Voglio poi anche ricordare con dolore da angoscia L'assassinio di suor Leonella sgorbati e della sua guardia del corpo cipria uccisi a Mogadiscio in un atto di atroce violenza la figura umana e morale di suor Leonella energie in questione con sempre maggiore chiarezza una persona che aveva dedicato l'intera sua vita alla città in più bisogno al colloquio e alla comprensione degli altri fino al sacrificio estremo mobilitato dalle ultime parole con le quali è la ha chiesto perdono per i suoi assassini Ho già avuto modo di esprimere i familiari alle consorelle di suor Leonella è più profondo cordoglio mio di Palazzo Madama
#  onorevoli colleghi rendo all'assemblea il triste annuncio della scomparsa del senatore Ignazio manusa deceduto improvvisamente il 24 agosto scorso ha 66 anni fortemente impegnato nella realtà politica della Sardegna il senatore manizha aveva una lunga carriera politica alle spalle già consigliere regionale sindaco di Oristano la tua città dal 81 al 84 Era stato eletto per la prima volta al Senato nella quattordicesima legislatura e quindi quella corrente nelle liste di Forza Italia recentemente aveva contribuito alla nascita del gruppo della Democrazia Cristiana indipendenti movimento per l'autonomia in Senato tu ce lo ricordiamo per il tratto mite e discreto e per la cinghia e sembrare presenza ai lavori parlamentari in aula è in commissione alla vedova signora Adriana ai figli ai colleghi del gruppo di appartenenza del suo partito agli elettori della Sardegna esprimo il cordoglio mio e personale dell'intera assemblea che vuoi Voglio poi anche ricordare con dolore da angoscia L'assassinio di suor Leonella sgorbati e della sua guardia del corpo cipria uccisi a Mogadiscio in un atto di atroce violenza la figura umana e morale di suor Leonella energie in questione con sempre maggiore chiarezza una persona che aveva dedicato l'intera sua vita alla città in più bisogno al colloquio e alla comprensione degli altri fino al sacrificio estremo mobilitato dalle ultime parole con le quali è la ha chiesto perdono per i suoi assassini Ho già avuto modo di esprimere i familiari alle consorelle di suor Leonella è più profondo cordoglio mio di Palazzo Madama nel momento in cui c'entrano accentuarsi le ragioni di contrapposizione tra le religioni dobbiamo tutti lavorare affinché la disponibilità al confronto e al dialogo interreligioso che il pontefice ha voluto ribadire nel suo discorso di domenica scorsa prevalga fra tu il mito L'assemblea non serve un momento di raccoglie
# -- Speech_speaker_7/ Speech_speaker_149 completato
# SPEAKER_10 235.642 8.47199999999998
# -- Error
#
# -- Speech_speaker_8/ Speech_speaker_149 completato
# SPEAKER_00 240.452 0.405
# -- Error
#
# -- Speech_speaker_9/ Speech_speaker_149 completato
# SPEAKER_09 247.117 4.674
#  chiesto la parola senatore Schipani ne ha facoltà
# -- Speech_speaker_10/ Speech_speaker_149 completato
# SPEAKER_13 254.07 100.57499999999999
#  è presidente Poche parole ma sentite a nome del mio gruppo per la scomparsa dolorosa dell'amico e collega mi ha detto manunta eletto in Forza Italia per la seconda legislatura collega caro persona saggia dai modi e dal temperamento oculato e razionale una persona che ci mancherà che mancherà al suo territorio la sua Sardegna i suoi amici tanti amici che abbiamo avuto modo di incontrare ad agosto in occasione delle sue esequie è stata una scomparsa improvvisa preferiamo ricordarlo seduto nei nostri banchi Come è la molto opportunamente ricordato sempre attento personaggio della politica locale Chiedi quella Nazionale attento i lavori dell'aula presente ma non soltanto con il corpo ma con la mente è sempre attento anche alle esigenze della tua regione non dimentico ne possiamo dimenticare le sue battaglie per il riconoscimento di alcune prerogative e di alcuni diritti in favore della sua terra della sua Sardegna e non dimentichiamo la sua storia la sua militanza politica nel territorio dal quale proviene è stato sindaco è stato assessore regionale è stato un uomo o di spicco che ha fatto crescere il tuo il suo territorio la sua isola
# -- Speech_speaker_11/ Speech_speaker_149 completato
# SPEAKER_10 355.455 0.422
#  E allora
# -- Speech_speaker_12/ Speech_speaker_149 completato
# SPEAKER_13 356.332 38.002999999999986
#  grazie Ma Nunzia è andato via improvvisamente nessuno di noi lo immaginava preferiamo ricordare il lui l'espressione quasi tornio Nama pagata e saggia di una persona che sapeva dove andava sapeva dove andava la sua politica la politica nella quale si era sempre identificato quella politica sulla politica per la quale aveva sempre dato il massimo di se stesso alla sua amata terra con questo Noi ci associamo al dolore dei suoi familiari dei suoi amici e di tutti i colori quali hanno creduto nel suo progetto Grazie
# -- Speech_speaker_13/ Speech_speaker_149 completato
# SPEAKER_09 394.335 8.623000000000047
#  Grazie fratello Schifano chiesto la parola il senatore Mantione ne ha facoltà
# -- Speech_speaker_14/ Speech_speaker_149 completato
# SPEAKER_08 406.974 131.89500000000004
#  Grazie Presidente abbiamo vissuto in questa aula nella scorsa legislatura dei momenti a volte molto Aspri molto intensi e mi ha detto di girarmi sulla mia sinistra e di incrociare immediatamente lo sguardo con quello di un collega al quale non potevi non essere affezionato Ignazio Ignazio Ma Nunzia una disponibilità che veniva espressa dal tratto somatico aveva una saggezza che rinvenibili nelle tue parole che non erano mai parole fuori posto ho parole dette a caso era una persona al di là dell' atteggiamento profondamente aperta è disponibile era che anche dalle poste Barricata c'è un modo comune di intendere la politica in modo che è fatto di passione che pazzo di coinvolgimento che è fatto di radicamento sul territorio io lo voglio ricordare così è una delle persone che quando io sono stato male in aula mi è stata più vicina di tante altre voglio ricordare quel sorriso profondo al quale Faceva riferimento anche il collega Schifani che era il sorriso di un uomo che sa già quello che accadrà domani per chi ha vissuto con profonda passione il suo passato e con grande consapevolezza loghi il Quotidiano in qualche modo continuerà a essere con noi con quel sorriso a nome del gruppo dell'Ulivo della Margherita e dei DS di tutti i colleghi che nella passata legislatura hanno avuto la possibilità di cono
#  Grazie Presidente abbiamo vissuto in questa aula nella scorsa legislatura dei momenti a volte molto Aspri molto intensi e mi ha detto di girarmi sulla mia sinistra e di incrociare immediatamente lo sguardo con quello di un collega al quale non potevi non essere affezionato Ignazio Ignazio Ma Nunzia una disponibilità che veniva espressa dal tratto somatico aveva una saggezza che rinvenibili nelle tue parole che non erano mai parole fuori posto ho parole dette a caso era una persona al di là dell' atteggiamento profondamente aperta è disponibile era che anche dalle poste Barricata c'è un modo comune di intendere la politica in modo che è fatto di passione che pazzo di coinvolgimento che è fatto di radicamento sul territorio io lo voglio ricordare così è una delle persone che quando io sono stato male in aula mi è stata più vicina di tante altre voglio ricordare quel sorriso profondo al quale Faceva riferimento anche il collega Schifani che era il sorriso di un uomo che sa già quello che accadrà domani per chi ha vissuto con profonda passione il suo passato e con grande consapevolezza loghi il Quotidiano in qualche modo continuerà a essere con noi con quel sorriso a nome del gruppo dell'Ulivo della Margherita e dei DS di tutti i colleghi che nella passata legislatura hanno avuto la possibilità di cono affondo Io voglio rinnovare il cordoglio Innanzitutto alla famiglia ma è un cordoglio che mi consenta presidente del chiuso davvero appartiene un poco a tutti quanti noi perché è venuto a mancare una persona di noi
# -- Speech_speaker_15/ Speech_speaker_149 completato
# SPEAKER_00 507.937 0.034
#  loghi Il Quotidiano
# -- Speech_speaker_16/ Speech_speaker_149 completato
# SPEAKER_09 540.843 7.84800000000007
#  grazie Sono Tore mansione parola al Senatore polledri
# -- Speech_speaker_17/ Speech_speaker_149 completato
# SPEAKER_11 552.47 112.894
#  Grazie Presidente a nome della Lega Nord ci associamo al dolore dei familiari per la proficua e anche di umana comprensione un'altra parola sentita ma per la perdita dell'amore di fronte della sorte vediamo che ti preoccupare per la perdita di
# -- Speech_speaker_18/ Speech_speaker_149 completato
# SPEAKER_10 683.96 0.523
# -- Error
#
# -- Speech_speaker_19/ Speech_speaker_149 completato
# SPEAKER_11 713.576 25.836
#  personaggio presidente che ha marcato non solamente la vita letteraria del paese ma credo anche la coscienza critica Credo che la nostra gratitudine Vada per le affermazioni anche così magari contestabili che hanno suscitato una profonda critica ma che sono state dettate dalla amore sincero se la nostra terra e per i valori dell'occidente
# -- Speech_speaker_20/ Speech_speaker_149 completato
# SPEAKER_09 741.167 29.091999999999985
#  Grazie imperatore polledri voglio soltanto sottolineare che a questo ricordo di Oriana Fallaci in piazza ciato il Senato io ho provveduto già nei giorni scorsi a nome mio e della nostro ramo del parlamento a comunicare i nostri sentimenti alla famiglia per una persona così importante per la cultura italiana di questi decenni Grazie la parola al presidente Matte
# -- Speech_speaker_21/ Speech_speaker_149 completato
# SPEAKER_03 772.453 0.388
# -- Error
#
# -- Speech_speaker_22/ Speech_speaker_149 completato
# SPEAKER_09 772.79 63.972999999999956
#  anch'io presidente Così come l'ho fatto con lei al lutto che ha colpito la famiglia del nostro collega ho conosciuto il senatore più di 30 anni fa perché in quell'occasione non ritrovato con lo stesso spirito di alcune delle nostre chiacchierate tanto da pochi giorni della sua morte alle parole grazie la parola senatore Sodano
# -- Speech_speaker_23/ Speech_speaker_149 completato
# SPEAKER_10 838.451 2.261
#  gli orari di chiusura
# -- Speech_speaker_24/ Speech_speaker_149 completato
# SPEAKER_16 845.015 46.17
#  Sì grazie presidente per esprimere anch'io a nome del gruppo di Rifondazione Comunista sinistra Europea il cordoglio per la scomparsa del senatore manuzza io insieme alla senatore malabarba abbiamo avuto modo di conoscere una passata legislatura E appunto come diceva lei presidente altri colleghi abbiamo avuto il modo soprattutto di apprezzarne il latte umano e appunto il tuo sorriso disarmante che anche nei momenti di Maggiore tensione in quest'aula aspetto è stato utilissimo per recuperare quella dialettica Democratica nell'aula del Senato della Repubblica quindi nella associarsi al dolore e al cordoglio per la scomparsa del primo ed estendere alla famiglia del tutto grazie
# -- Speech_speaker_25/ Speech_speaker_149 completato
# SPEAKER_09 892.333 5.316
#  Grazie senatore Sodano la parola al presidente
# -- Speech_speaker_26/ Speech_speaker_149 completato
# SPEAKER_07 901.395 25.38
#  il gruppo 0 purtroppo ho avuto
# -- Speech_speaker_27/ Speech_speaker_149 completato
# SPEAKER_09 927.872 3.223
#  Grazie Salvatore D'Onofrio a però al senatore maschi
# -- Speech_speaker_28/ Speech_speaker_149 completato
# SPEAKER_10 934.942 0.54
# -- Error
#
# -- Speech_speaker_29/ Speech_speaker_149 completato
# SPEAKER_02 938.3 97.352
#  nella sociali naturalmente a tutto ciò che è stato detto sui gnazio io potrei aggiungere tante altre cose perché assieme abbiamo fatto diverse campagne elettorali Lo conosco da tanti anni e per tanti anni le nostre strade hanno percorso la stessa percorso la testa via Però credo di averli di associarmi anche ricordando qualcosa che non è stato molto consueto ultimamente nelle nostre nelle nostre aule Ignazio stava male da tanto tempo e molto spesso il Chissà che di fronte a certe malattie è consigliabile ridurre l'impegno politico ma era tanto l'amore è il tanto il legame per gli elettori che le avevo dato la fiducia che anche nei momenti difficili salute voleva essere sempre presente in quest'aula questo lo dico per ricordare ai tanti colleghi che talvolta manca nella nostra attività quanto tempo Tante il suo ruolo e quindi quanto abbia dato nel proprio col proprio lavoro di esempio Ignazio Ignazio che insieme a me ad altri e altri parlamentari di Forza Italia hanno voluto anche aiutare gli amici della Democrazia Cristiana del Movimento per l'autonomia ad avere la dignità di un gruppo per poter svolgere appieno la loro azione Ecco perché mi associo al dolore dei familiari e voglio portare a nome del gruppo della dici il nostro contributo di affetto ad Ignazio
# -- Speech_speaker_30/ Speech_speaker_149 completato
# SPEAKER_09 1037.61 3.443
#  grazie Siamo tornati dalla parola ministro
# -- Speech_speaker_31/ Speech_speaker_149 completato
# SPEAKER_04 1043.617 4.573
#  si dà il caso che questa volta era presidente del governo
# -- Speech_speaker_32/ Speech_speaker_149 completato
# SPEAKER_03 1045.423 0.034
# -- Error
#
# -- Speech_speaker_33/ Speech_speaker_149 completato
# SPEAKER_04 1048.798 113.11300000000006
#  Governolo esprima la solidarietà alla famiglia e la vicinanza al gruppo di Forza Italia di cui espressione politica un amico del senatore Manu ne ricordi tratti di un uomo mite ma anche determinato e di questo tuo profondo affetto e legame con la realtà territoriale di Oristano è onesto questo che forse gli ultimi tempi anche per ragioni più varie a tirarti a continuazione politologiche questo nesso del rapporto territorio Chi è presente alle istituzioni mi pare molto più lattica lo ricordo Con grande affetto per la tua umanità e quindi esprimo Sinceramente questa mia doglianza interni umani voglio anche il signor presidente che lei ha ricordato turno nella è a nome del governo anche questo primo una forma di partecipazione sia come Cristiano convinto sia in solidarietà Laica nella mia espressione istituzionale Io mi auguro che il come ha dichiarato anche recentemente il primo pontefice nonostante queste tragiche tragici episodi contiene possa continuare quel dialogo tra le religioni E con questo evidentemente da anche l'idea che non c'è solitudine da parte il contedino esprimere le proprie considerazioni Ma c'è vicinanza Per quanto mi riguarda da ultimo per la palla uno può avere avuto anch'io ho avuto perplessità in ordine l'opinionista brutto di recente che la palla esce ha manifestato in questo caso non ricordo che dedico con continuità da giornalista anche se modesto Evidentemente mi fa piacere ricordare a questa una che il problema tra di noi e nei confronti alla Fallaci non è condividere il test opinioni ma rispettare le opinioni degli altri nel rispetto di suo figlio differenza la mia mi inchino rispetto anche a Oriana Fallaci
# -- Speech_speaker_34/ Speech_speaker_149 completato
# SPEAKER_09 1163.16 283.5329999999999
ti Provera ben altro ben altro progetto è che su quel su quel progetto non viene alzata la condivisione dell'amministratore delegato abbiamo capito a posteriori le motivazioni di quella rabbia del presidente del consiglio perché adesso è proposto e non erano state accolte bene si è voluto prendere la parte il presidente del consiglio le distanze su quello che era venuto e si è sostanzialmente tentato di far credere al mondo intero il consiglio conosceva l'operato del tuo consulente economico che lavorava a Palazzo Chigi e che inviava dei doppie su carta intestata di Palazzo Chigi Credo che effettivamente tu questo aspetto chiarezza andrebbe fatta così come chiede se abbiamo chiesto venisse fatto nel parlamento c'è stato detto che la roba da matti ti ha detto che il Governo era pronto a riferire sulla vicenda complessiva su quella che riguardava una tematica che interessava 90000 posti di lavoro interessava un'azienda che fa che fa parte del sistema Italia quello della telecomunicazione sulla Quartu la tua efficienza si misura la competitività di un paese si è offerta la possibilità di dibattere con dei ministri che venissero riferire su questo argomento in senso lato Allora noi abbiamo chiesto con forza ma anche con senso di responsabilità la presenza del presidente del consiglio perché quel di  ...
# -- Speech_speaker_36/ Speech_speaker_149 completato
# SPEAKER_00 1861.802 0.017
#  di essere scherniti
# -- Speech_speaker_37/ Speech_speaker_149 completato
# SPEAKER_10 1871.505 0.017
#  Adesso vediamo a fettine
# -- Speech_speaker_38/ Speech_speaker_149 completato
# SPEAKER_13 1881.815 101.571
#  e addirittura Ascoltiamo una disponibilità e presente al consiglio che deciderà dove andare in quale dei due rami del parlamento se la camera è il Senato poi ti valuterà In quale ramo del parlamento signor presidente il Parlamento e lei lo sa è composto da due rami del parlamento che hanno pari Funzione legislativa pari dignità politica E rivendicano una parità di trattamento sul tema così delicato quale Quello della vicenda Telecom e mi auguro Mi auguro fortemente che anche i colleghi della maggioranza condividono questa nostra espressione e che rivendichino la presenza del presidente del consiglio in entrambi i rami del parlamento evitiamo conflitti tra camera e Senato non ne non sta nel nostro costume vogliamo allontanare questa ipotesi Anche perché su una tematica e tu una vicenda così delicata riteniamo che il presente al consiglio debba Informare il Parlamento nella sua interezza nella sua compiutezza Ecco perché non condividiamo questa proposta di calendario e Ci permettiamo di introdurre una variante che preveda la destinazione di una seduta pomeridiana e la giornata di giovedì perché il Parlamento il Senato possa discutere di questo tema sulla logica anche di ordini del giorno presentati da questo posizione con l'assistenza la presenza del presidente del consiglio che Avendo tolto la riserva essendosi dichiarato disponibile a venire il ramo del parlamento potrà fare un piccolo sacrificio una volta atterrato a Ciampino dedicare qualche ora ad ascoltare e ad essere ascoltato da noi su una vicenda così delicata che interessa tutti interessa la politica interessa la democrazia del nostro paese
# -- Speech_speaker_39/ Speech_speaker_149 completato
# SPEAKER_09 1987.537 4.118
#  Grazie senatore Schipani la parola al presidente Matteoli
# -- Speech_speaker_40/ Speech_speaker_149 completato
# SPEAKER_18 1991.655 3.2560000000000855
#  al presidente Matteoli
# -- Speech_speaker_41/ Speech_speaker_149 completato
# SPEAKER_09 1995.857 247.85999999999967
generazione che ci fa è un caso avvenuto Quando fu costretto a dimettersi perché scappò dal carcere CAP le responsabilità Erano veramente dei suoi collaboratori e abbiamo assistito alle dimissioni di un altro ministro del precedente governo che alcuni suoi collaboratori Furono coinvolte tutto da dimostrare ma comunque furono coinvolti in vicende mi riferisco al collega Storace il Parlamento in questo modo Noi abbiamo sostenuto in conferenza dei capigruppo e lo sosteniamo qui che lavori parlamentari non potevano riprendere se non prima non avessimo ascoltato e questo non è stato possibile quindi non possiamo votare assolutamente il calendario perché viene sottoposto i giornali Tutti i giornali dal più piccolo al più grande per 10 giorni Una settimana Le prime quattro pagine dei giornali 5 pagine dei giornali sono state tutte su questo argomento anche la stampa estera si è soffermata su questo argomento e il Parlamento deve aspettare ancora 10 giorni per ascoltare la parola è presidente del consiglio Lo consideriamo assolutamente inaccettabile inaccettabile voteremo Quindi contro questo che ci viene proposto Grazie Presidente Matteoli la parola senatore Russo spena
# -- Speech_speaker_42/ Speech_speaker_149 completato
# SPEAKER_03 2245.623 292.1579999999999
#  Grazie Presidente noi voteremo a favore di questo calendario E mo ti dirò molto brevemente per chi calendario che insieme abbiamo costruito tutti i presidenti di gruppo insieme a lei presidente nella conferenza presidenti di gruppo E sostanzialmente per due motivi Il primo mi sembra si trova tutti concordi Questo è un calendario che prevede l'istituzione la commissione di inchiesta sul fenomeno della mafia l'istituzione una commissione d'inchiesta Sul ciclo dei rifiuti l'istituzione della commissione inchiesta sugli infortuni sul lavoro che riteniamo urgente importante è l'istituzione di una commissione d'inchiesta sull'uranio impoverito e abbiamo chiesto venisse inserito è stato accettato il provvedimento è passato se non sbaglio all'unanimità in quarta commissione e quindi riteniamo che sia stato molto positivo e inserirla immediatamente per la discussione in aula punto mi pare vi sia stata una distinzione da parte dei presidenti di gruppo dell'opposizione quel che riguarda appunto la le comunicazioni del presidente del consiglio che dopo una discussione dopo un'ampia discussione è coinvolto anche il governo ha deciso di intervenire in Parlamento il 28 settembre Io credo che occorra cogliere la positività di questo intervento del presidente del consiglio io credo che non mi siano è questo è un punto di rilievo personali in questa vicenda del consiglio ci pare che sia molto negativo il fatto che c'ha ora lo dicevo nel presidente Schifani è presidente Matteoli si sente in qualche modo a individuare Invece un percorso
# ...
#  grazie signor presidente signor presidente del Senato onorevoli senatori Ritengo che la questione pregiudiziale sia completamente destituita di ogni fondamento sono Anzi convinto che il suo accoglimento presenterebbe problemi e dubbi più consistenti sotto il profilo della legittimità costituzionale già in altra sede è l'attuale vice presidente del Consiglio Superiore della Magistratura l'onorevole Mancino ho avuto avuto occasione di segnalare i danni anche gravi all'attività del Consiglio Superiore della Magistratura e degli uffici giudiziari tempi determinati dall'entrata in vigore ed alle ficaccia dei tre dei decreti che ci riguardano ha usato anche Tony piuttosto pesanti parlando in certe situazioni di blocco di rischio di dell'attività e anche di situazione di caos Ritengo che l'entrata in vigore di questi tre decreti legislativi in particolare ti presenti in contrasto con l'articolo 97 della Costituzione che quello che Tutela il buon andamento e l'imparzialità della pubblica amministrazione stessa ma ci sono altri profili di dubbio di legittimità costituzionale più consistenti i primi riguardano il primo decreto che ha il decreto numero 106 quello relativo alla gerarchizzazione delle procure della Repubblica e le critiche di maggior rilievo vengono rivolte in particolar modo nei confronti di questo decreto legislativo perché questo decreto inficia gravemente il principio costituzionale dell'Indipendenza della magistratura in particolare l'art 104 della Costituzione quello che fa riferimento alla magistratura come ordine autonomo e indipendente da ogni altro potere l'articolo 100 e 9 e dice che l'autorità giudiziaria dispone direttamente come autorità giudiziaria e come potere diffuso della polizia giudiziaria è l'articolo 112 che fa riferimento al pubblico ministero che ha l'obbligo di esercitare l'azione penale le norme che entrano entrerebbero che sono entrate in vigore che continuerebbero a produrre effetto determinerebbero delle lesioni di questi principi costituzionali garantiti la magistratura ha un sistema giudiziario un modello di sistema giudiziario che viene definito di potere di punto perché viene ritenuto il più idoneo a una democrazia moderna proprio impedendo un capillare diffuso esercizio dell'azione penale inficiare quella che la natura stessa di questo potere diffuso altri problemi sono poi collegati al secondo decreto entrato in vigore che il numero 109 quello relativo alla azione disciplinare e in particolare alla tipizzazione per la quale Peraltro non siamo contrari ma in particolare alla obbligatorietà dell'azione disciplinare In ogni caso è strettamente collegata Come complessità è come rischio di danno questa entrata in vigore con quello che dicevo in materia di indipendenza autonomia della magistratura in riferimento all'esercizio del potere del pubblico ministero l'azione disciplinare così come è stata prospettata e così con entrata in vigore crea dei problemi particolari all'interno del consiglio tetto rischiando di creare con te Quanto viene detto un blocco dell'attività dell'attività disciplinare da parte del consiglio superiore e dall'altra parte proprio per il numero eccessivo di azioni di segnalazioni disposti nei confronti di magistrati Così come vengono effettuate si creerebbe da una parte il blocco degli organi che vengono che sono stati istituzionalmente incaricati di prestazioni spinare e dall'altra questo comporterebbe il raggiungimento in tempi brevissimi del termine della prescrizione che sappiamo essere fissato in un anno quindi da una parte la moltiplicazione del numero dei procedimenti e dall'altro l'estinzione dei procedimenti che non rispondono alla tipologia prevista sono i danni maggiori altra questione riguarda il terzo decreto legislativo che dovrebbe entrare in vigore che il numero 170 in questa situazione e per chi non apparecchiano ricordare come la così come è stata fatta di concorsi ripetuti per strati il problema della progressione in carriera costringerebbe i singoli ...
#  grazie signor presidente signor presidente del Senato onorevoli senatori Ritengo che la questione pregiudiziale sia completamente destituita di ogni fondamento sono Anzi convinto che il suo accoglimento presenterebbe problemi e dubbi più consistenti sotto il profilo della legittimità costituzionale già in altra sede è l'attuale vice presidente del Consiglio Superiore della Magistratura l'onorevole Mancino ho avuto avuto occasione di segnalare i danni anche gravi all'attività del Consiglio Superiore della Magistratura e degli uffici giudiziari tempi determinati dall'entrata in vigore ed alle ficaccia dei tre dei decreti che ci riguardano ha usato anche Tony piuttosto pesanti parlando in certe situazioni di blocco di rischio di dell'attività e anche di situazione di caos Ritengo che l'entrata in vigore di questi tre decreti legislativi in particolare ti presenti in contrasto con l'articolo 97 della Costituzione che quello che Tutela il buon andamento e l'imparzialità della pubblica amministrazione stessa ma ci sono altri profili di dubbio di legittimità costituzionale più consistenti i primi riguardano il primo decreto che ha il decreto numero 106 quello relativo alla gerarchizzazione delle procure della Repubblica e le critiche di maggior rilievo vengono rivolte in particolar modo nei confronti di questo decreto legislativo perché questo decreto inficia gravemente il principio costituzionale dell'Indipendenza della magistratura in particolare l'art 104 della Costituzione quello che fa riferimento alla magistratura come ordine autonomo e indipendente da ogni altro potere l'articolo 100 e 9 e dice che l'autorità giudiziaria dispone direttamente come autorità giudiziaria e come potere diffuso della polizia giudiziaria è l'articolo 112 che fa riferimento al pubblico ministero che ha l'obbligo di esercitare l'azione penale le norme che entrano entrerebbero che sono entrate in vigore che continuerebbero a produrre effetto determinerebbero delle lesioni di questi principi costituzionali garantiti la magistratura ha un sistema giudiziario un modello di sistema giudiziario che viene definito di potere di punto perché viene ritenuto il più idoneo a una democrazia moderna proprio impedendo un capillare diffuso esercizio dell'azione penale inficiare quella che la natura stessa di questo potere diffuso altri problemi sono poi collegati al secondo decreto entrato in vigore che il numero 109 quello relativo alla azione disciplinare e in particolare alla tipizzazione per la quale Peraltro non siamo contrari ma in particolare alla obbligatorietà dell'azione disciplinare In ogni caso è strettamente collegata Come complessità è come rischio di danno questa entrata in vigore con quello che dicevo in materia di indipendenza autonomia della magistratura in riferimento all'esercizio del potere del pubblico ministero l'azione disciplinare così come è stata prospettata e così con entrata in vigore crea dei problemi particolari all'interno del consiglio tetto rischiando di creare con te Quanto viene detto un blocco dell'attività dell'attività disciplinare da parte del consiglio superiore e dall'altra parte proprio per il numero eccessivo di azioni di segnalazioni disposti nei confronti di magistrati Così come vengono effettuate si creerebbe da una parte il blocco degli organi che vengono che sono stati istituzionalmente incaricati di prestazioni spinare e dall'altra questo comporterebbe il raggiungimento in tempi brevissimi del termine della prescrizione che sappiamo essere fissato in un anno quindi da una parte la moltiplicazione del numero dei procedimenti e dall'altro l'estinzione dei procedimenti che non rispondono alla tipologia prevista sono i danni maggiori altra questione riguarda il terzo decreto legislativo che dovrebbe entrare in vigore che il numero 170 in questa situazione e per chi non apparecchiano ricordare come la così come è stata fatta di concorsi ripetuti per strati il problema della progressione in carriera costringerebbe i singoli ...
#  grazie signor presidente signor presidente del Senato onorevoli senatori Ritengo che la questione pregiudiziale sia completamente destituita di ogni fondamento sono Anzi convinto che il suo accoglimento presenterebbe problemi e dubbi più consistenti sotto il profilo della legittimità costituzionale già in altra sede è l'attuale vice presidente del Consiglio Superiore della Magistratura l'onorevole Mancino ho avuto avuto occasione di segnalare i danni anche gravi all'attività del Consiglio Superiore della Magistratura e degli uffici giudiziari tempi determinati dall'entrata in vigore ed alle ficaccia dei tre dei decreti che ci riguardano ha usato anche Tony piuttosto pesanti parlando in certe situazioni di blocco di rischio di dell'attività e anche di situazione di caos Ritengo che l'entrata in vigore di questi tre decreti legislativi in particolare ti presenti in contrasto con l'articolo 97 della Costituzione che quello che Tutela il buon andamento e l'imparzialità della pubblica amministrazione stessa ma ci sono altri profili di dubbio di legittimità costituzionale più consistenti i primi riguardano il primo decreto che ha il decreto numero 106 quello relativo alla gerarchizzazione delle procure della Repubblica e le critiche di maggior rilievo vengono rivolte in particolar modo nei confronti di questo decreto legislativo perché questo decreto inficia gravemente il principio costituzionale dell'Indipendenza della magistratura in particolare l'art 104 della Costituzione quello che fa riferimento alla magistratura come ordine autonomo e indipendente da ogni altro potere l'articolo 100 e 9 e dice che l'autorità giudiziaria dispone direttamente come autorità giudiziaria e come potere diffuso della polizia giudiziaria è l'articolo 112 che fa riferimento al pubblico ministero che ha l'obbligo di esercitare l'azione penale le norme che entrano entrerebbero che sono entrate in vigore che continuerebbero a produrre effetto determinerebbero delle lesioni di questi principi costituzionali garantiti la magistratura ha un sistema giudiziario un modello di sistema giudiziario che viene definito di potere di punto perché viene ritenuto il più idoneo a una democrazia moderna proprio impedendo un capillare diffuso esercizio dell'azione penale inficiare quella che la natura stessa di questo potere diffuso altri problemi sono poi collegati al secondo decreto entrato in vigore che il numero 109 quello relativo alla azione disciplinare e in particolare alla tipizzazione per la quale Peraltro non siamo contrari ma in particolare alla obbligatorietà dell'azione disciplinare In ogni caso è strettamente collegata Come complessità è come rischio di danno questa entrata in vigore con quello che dicevo in materia di indipendenza autonomia della magistratura in riferimento all'esercizio del potere del pubblico ministero l'azione disciplinare così come è stata prospettata e così con entrata in vigore crea dei problemi particolari all'interno del consiglio tetto rischiando di creare con te Quanto viene detto un blocco dell'attività dell'attività disciplinare da parte del consiglio superiore e dall'altra parte proprio per il numero eccessivo di azioni di segnalazioni disposti nei confronti di magistrati Così come vengono effettuate si creerebbe da una parte il blocco degli organi che vengono che sono stati istituzionalmente incaricati di prestazioni spinare e dall'altra questo comporterebbe il raggiungimento in tempi brevissimi del termine della prescrizione che sappiamo essere fissato in un anno quindi da una parte la moltiplicazione del numero dei procedimenti e dall'altro l'estinzione dei procedimenti che non rispondono alla tipologia prevista sono i danni maggiori altra questione riguarda il terzo decreto legislativo che dovrebbe entrare in vigore che il numero 170 in questa situazione e per chi non apparecchiano ricordare come la così come è stata fatta di concorsi ripetuti per strati il problema della progressione in carriera costringerebbe i singoli ...
# -- Speech_speaker_146/ Speech_speaker_149 completato
# SPEAKER_10 10007.921 0.152
#  concludo subito
# -- Speech_speaker_147/ Speech_speaker_149 completato
# SPEAKER_17 10042.953 0.034
#  il governo
# -- Speech_speaker_148/ Speech_speaker_149 completato
# SPEAKER_09 10043.544 45.883
#  Grazie senatore Carlton noi dichiariamo chiusa la seduta ci sono ancora iscritti a parlare sulla discussione sul sospensiva il pregiudiziale i senatori di Lello e Barbato riprendiamo domani alla la seduta di domani alle 9:30 con all'ordine del giorno prosecuzione della discussione sul disegno di legge 635 nel pomeriggio la seduta pomeridiana con inizio alle 16:30 commerciali in legge del decreto-legge 15 settembre 2006 recante disposizioni di adeguamento alla sentenza della Corte di Giustizia delle comunità europee in materia di detraibilità dell'IVA la seduta
# -- Speech_speaker_149/ Speech_speaker_149 completato
# Terminato: Leg15NumSed33
# Execution complete!

# %% [markdown]
# # Include la conversione da acc a wav

# %%
import speech_recognition as sr
from deepmultilingualpunctuation import PunctuationModel
import time
import csv
import ffmpeg
import pandas as pd
import os
import sys


pathname = os.path.dirname(sys.argv[0])

# if os.path.exists("./../../../../../data/senato_project/data/speech2text/" + filename + ".txt"):
#     continue
filename = "Leg15NumSed22"
# aac_file = "./../../../../../data/senato_project/data/download_convert_video_aac/" + filename + ".aac"
aac_file = "./" + filename + ".aac"
wav_file = "./" + filename + ".wav"

print("Inizio conversione wav")
stream = ffmpeg.input(aac_file)
stream = ffmpeg.output(stream, wav_file)
ffmpeg.run(stream)
print("Conversione wav completata")

# initialize the recognizer
r = sr.Recognizer()

# mettere la punteggiatura al testo estratto
model = PunctuationModel()

chunk_size = 120 # 2 minutes in seconds

audio_file = sr.AudioFile(wav_file)


f_text_speakers = open('../../data/speech2text_diarization/' + filename + '.csv', 'w')
writer_text_speakers = csv.writer(f_text_speakers, lineterminator='\n')
writer_text_speakers.writerow(["id_speaker", "text", "offset_video", "duration"])

print("Inizio: " + filename)
with audio_file as source:
    print(source.DURATION)
    duration_audio = source.DURATION
    with open('../../data/convert_rttm_to_csv/' + filename + '.csv', 'r') as file:
        reader = csv.reader(file)
        num_total_speech_speaker = sum(1 for _ in reader) - 1
        print(num_total_speech_speaker)
        file.seek(0)
        next(reader)  # Salta la prima riga (nomi delle colonne)
        count_speech_speaker = 1
        for row in reader:
            whole_text_speaker = ""
            id_speaker = row[0]
            start_speaker_offset = float(row[1]) - 2
            duration_speech_speaker = float(row[2])
            if start_speaker_offset < 0:
                start_speaker_offset = 0
            print(id_speaker + " " + str(start_speaker_offset) + " " + str(duration_speech_speaker))
            end_speaker_offset = start_speaker_offset + duration_speech_speaker
            if duration_audio > end_speaker_offset + 1:
                end_speaker_offset = end_speaker_offset + 1
            else:
                end_speaker_offset = duration_audio
            for i in range(int(start_speaker_offset), int(end_speaker_offset), chunk_size):
                start = i
                end = min(i + chunk_size, end_speaker_offset)
                source = sr.AudioFile(wav_file)
                with source as s:
                    r.adjust_for_ambient_noise(s)
                    try:
                        audio_data = r.record(s, duration=end-start, offset=start)
                        text = r.recognize_google(audio_data, language='it-IT')
                        whole_text_speaker += " " + text
                        print(whole_text_speaker)
                    except Exception as e:
                        print("-- Error")
                        print(e)
            print("-- Speech_speaker_" + str(count_speech_speaker) +"/ Speech_speaker_" + str(num_total_speech_speaker) + " completato")
            count_speech_speaker += 1
            try:
                result_text_punctuation = model.restore_punctuation(whole_text_speaker)
                writer_text_speakers.writerow([id_speaker, result_text_punctuation, start_speaker_offset, duration_speech_speaker])
            except Exception as e:
                pass



# scrivere il risultato dell'inserimento della punteggiatura su file
# os.remove(wav_file)
f_text_speakers.close()
print("Terminato: " + filename)

print("Execution complete!")
# Out:
# c:\Users\andre\anaconda3\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Inizio conversione wav
